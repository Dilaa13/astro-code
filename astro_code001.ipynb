# %%
import numpy as np #for analyzing and processing data
import matplotlib.pyplot as plt #to visualizing data
from astropy.io import fits #to read/open the astronomical data
import aplpy #visualizing the data in more better way

# %%
astro_data = fits.open("HorseHead.fits")

# %%
astro_data
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x00000160576DB0B0>, <astropy.io.fits.hdu.table.TableHDU object at 0x00000160622D11C0>]

# %%
astro_data.info()
# Out:
# Filename: HorseHead.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     161   (891, 893)   int16
#   1  er.mask       1 TableHDU        25   1600R x 4C   [F6.2, F6.2, F6.2, F6.2]

# %%
astro_data[0].header
# Out:
# SIMPLE  =                    T /FITS: Compliance
# BITPIX  =                   16 /FITS: I*2 Data
# NAXIS   =                    2 /FITS: 2-D Image Data
# NAXIS1  =                  891 /FITS: X Dimension
# NAXIS2  =                  893 /FITS: Y Dimension
# EXTEND  =                    T /FITS: File can contain extensions
# DATE    = '2014-01-09        '  /FITS: Creation Date
# ORIGIN  = 'STScI/MAST'         /GSSS: STScI Digitized Sky Survey
# SURVEY  = 'SERC-ER '           /GSSS: Sky Survey
# REGION  = 'ER768   '           /GSSS: Region Name
# PLATEID = 'A0JP    '           /GSSS: Plate ID
# SCANNUM = '01      '           /GSSS: Scan Number
# DSCNDNUM= '00      '           /GSSS: Descendant Number
# TELESCID=                    4 /GSSS: Telescope ID
# BANDPASS=                   36 /GSSS: Bandpass Code
# COPYRGHT= 'AAO/ROE '           /GSSS: Copyright Holder
# SITELAT =              -31.277 /Observatory: Latitude
# SITELONG=              210.934 /Observatory: Longitude
# ...

# %%
image_data = astro_data[0].data

# %%
image_data
# Out:
# array([[ 7201,  6642,  6642, ...,  9498,  9498, 10057],
#        [ 6642,  6363,  6642, ..., 10057, 10616, 10616],
#        [ 6922,  6642,  6922, ..., 10337, 11175, 10616],
#        ...,
#        [ 5412,  5132,  5412, ..., 13000, 12580, 12021],
#        [ 5796,  5517,  5796, ..., 12546, 12546, 11987],
#        [ 5796,  5796,  6076, ..., 11987, 12546, 12546]], dtype='>i2')

# %%
plt.imshow(image_data) #raw image

# %%
plt.imshow(image_data, cmap= "inferno")

# %%
print("mean = ", np.mean(image_data))
print("std = ", np.std(image_data))
print("min = ", np.min(image_data))
print("max = ", np.max(image_data))
print("median = ", np.median(image_data))
# Out:
# mean =  9831.481676287574
# std =  3032.3927542049046
# min =  3759
# max =  22918
# median =  9658.0

# %%
plt.hist(image_data)
# Out:
# (array([[232., 624.,  37., ...,   0.,   0.,   0.],
#         [212., 634.,  45., ...,   0.,   0.,   0.],
#         [203., 645.,  43., ...,   0.,   0.,   0.],
#         ...,
#         [  0.,   0.,  47., ...,   1.,   0.,   0.],
#         [  0.,   0.,  50., ...,   0.,   0.,   0.],
#         [  0.,   0.,  41., ...,   0.,   0.,   0.]]),
#  array([ 3759. ,  5674.9,  7590.8,  9506.7, 11422.6, 13338.5, 15254.4,
#         17170.3, 19086.2, 21002.1, 22918. ]),
#  <a list of 891 BarContainer objects>)

# %%
plt.hist(image_data.flatten())
# Out:
# (array([ 32993., 230794., 128002., 124267., 162939.,  91814.,  22212.,
#           1201.,    786.,    655.]),
#  array([ 3759. ,  5674.9,  7590.8,  9506.7, 11422.6, 13338.5, 15254.4,
#         17170.3, 19086.2, 21002.1, 22918. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(image_data.flatten() , bins = "auto")
# Out:
# (array([1.0000e+00, 0.0000e+00, 1.0000e+00, 3.0000e+00, 1.0000e+01,
#         5.4000e+01, 8.0000e+01, 2.0100e+02, 4.1400e+02, 7.4600e+02,
#         1.3830e+03, 2.0160e+03, 3.0260e+03, 4.2490e+03, 5.5490e+03,
#         7.1710e+03, 8.0890e+03, 9.5940e+03, 1.0663e+04, 1.1307e+04,
#         1.2104e+04, 1.2673e+04, 1.3176e+04, 1.4565e+04, 1.5218e+04,
#         1.5007e+04, 1.4787e+04, 1.5280e+04, 1.4974e+04, 1.5004e+04,
#         1.5140e+04, 1.4559e+04, 1.3922e+04, 1.2821e+04, 1.2500e+04,
#         1.1581e+04, 1.0750e+04, 9.9400e+03, 9.6310e+03, 8.7210e+03,
#         8.3270e+03, 7.9500e+03, 7.0470e+03, 6.4430e+03, 6.1070e+03,
#         5.2880e+03, 5.3750e+03, 4.9840e+03, 4.6900e+03, 4.4270e+03,
#         4.2410e+03, 4.5490e+03, 4.5170e+03, 4.6400e+03, 5.0920e+03,
#         5.3510e+03, 5.9310e+03, 6.9280e+03, 7.5590e+03, 7.8760e+03,
#         8.2450e+03, 8.3850e+03, 8.9250e+03, 9.0700e+03, 9.2730e+03,
#         9.4960e+03, 8.9840e+03, 9.4460e+03, 9.4770e+03, 9.7270e+03,
# ...

# %%
plt.hist(image_data.flatten() , bins = "auto")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ap = aplpy.FITSFigure("HorseHead.fits")
ap.show_grayscale()
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 48247.575694 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: AstropyDeprecationWarning: CoordinateHelper.ticks should not be accessed directly and is deprecated [astropy.visualization.wcsaxes.coordinate_helpers]
# INFO: Auto-setting vmin to  3.681e+03 [aplpy.core]
# INFO: Auto-setting vmax to  1.813e+04 [aplpy.core]

# %%
ap = aplpy.FITSFigure("HorseHead.fits")
ap.show_colorscale(cmap='gist_heat')
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 48247.575694 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: AstropyDeprecationWarning: CoordinateHelper.ticks should not be accessed directly and is deprecated [astropy.visualization.wcsaxes.coordinate_helpers]
# INFO: Auto-setting vmin to  3.685e+03 [aplpy.core]
# INFO: Auto-setting vmax to  1.897e+04 [aplpy.core]

# %%
ap = aplpy.FITSFigure('HorseHead.fits') # loading the image as an aplpy object
ap.show_colorscale(cmap='gist_heat') #displaying the image..
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 48247.575694 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: AstropyDeprecationWarning: CoordinateHelper.ticks should not be accessed directly and is deprecated [astropy.visualization.wcsaxes.coordinate_helpers]
# INFO: Auto-setting vmin to  3.743e+03 [aplpy.core]
# INFO: Auto-setting vmax to  1.836e+04 [aplpy.core]

# %%
# if you happen to have rgb data you can also use that..

# displaying the image using a different color scale

# here we will also overlay some more data, like lets say highlighting a certain part of the image using some contours...

ap.show_rgb('2MASS_arcsinh_color.png')
ap.tick_labels.set_font(size='small')
ap.show_contour('mips_24micron.fits', colors='white')
